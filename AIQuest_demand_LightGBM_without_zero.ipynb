# %%
# !pip install signate

from googleapiclient.discovery import build
import io, os
from googleapiclient.http import MediaIoBaseDownload
from google.colab import auth


auth.authenticate_user()

drive_service = build('drive', 'v3')
results = drive_service.files().list(
        q="name = 'signate.json'", fields="files(id)").execute()
signate_api_key = results.get('files', [])

filename = "/root/.signate/signate.json"
os.makedirs(os.path.dirname(filename), exist_ok=True)

request = drive_service.files().get_media(fileId=signate_api_key[0]['id'])
fh = io.FileIO(filename, 'wb')
downloader = MediaIoBaseDownload(fh, request)
done = False
while done is False:
    status, done = downloader.next_chunk()
    print("Download %d%%." % int(status.progress() * 100))
os.chmod(filename, 600)
# Out:
# Collecting signate
#   Downloading signate-0.9.8-py3-none-any.whl (37 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from signate) (2.8.2)
# Collecting urllib3>=1.26.4
#   Downloading urllib3-1.26.7-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 8.6 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from signate) (2021.5.30)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from signate) (7.1.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from signate) (0.8.9)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from signate) (1.15.0)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9672 sha256=701dfe185a343527e5b3cf5a7e92f73b7fec35b0c5615e626e0fbb9130c8a01d
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget, urllib3, signate
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# requests 2.23.0 requires urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1, but you have urllib3 1.26.7 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed signate-0.9.8 urllib3-1.26.7 wget-3.2
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Download 100%.

# %%
! signate list
! signate files --competition-id=492
! signate download --competition-id=492
# Out:
#   competitionId  title                                                                  closing     prize            submitters
# ---------------  ---------------------------------------------------------------------  ----------  -------------  ------------
#               1  【練習問題】銀行の顧客ターゲティング                                   -                                  5160
#              24  【練習問題】お弁当の需要予測                                           -                                  6333
#              27  【練習問題】Jリーグの観客動員数予測                                    -                                  1433
#             100  【練習問題】手書き文字認識                                             -           Knowledge               170
#             102  【練習問題】タイタニックの生存予測                                     -           Knowledge              1059
#             103  【練習問題】音楽ラベリング                                             -           Knowledge                61
#             104  【練習問題】スパムメール分類                                           -           Knowledge               131
#             105  【練習問題】毒キノコの分類                                             -           Knowledge               244
#             106  【練習問題】アワビの年齢予測                                           -           Knowledge               352
#             107  【練習問題】国勢調査からの収入予測                                     -           Knowledge               522
#             108  【練習問題】画像ラベリング（20種類）                                   -           Knowledge               220
#             112  【練習問題】ワインの品種の予測                                         -           Knowledge               296
#             113  【練習問題】山火事の消失面積予測                                       -           Knowledge               186
#             114  【練習問題】レンタル自転車の利用者数予測                               -           Knowledge               369
#             115  【練習問題】アヤメの分類                                               -           Knowledge               335
#             116  【練習問題】活動センサーログからの動作予測                             -           Knowledge                44
#             118  【練習問題】テニスの試合結果の予測                                     -           Knowledge               109
#             121  【練習問題】自動車の走行距離予測                                       -           Knowledge              1322
#             122  【練習問題】自動車の評価                                               -           Knowledge               302
#             123  【練習問題】オゾンレベルの分類                                         -           Knowledge                36
#             124  【練習問題】ボットの判別                                               -           Knowledge               288
#             125  【練習問題】ガラスの分類                                               -           Knowledge               129
#             126  【練習問題】林型の分類                                                 -           Knowledge                27
#             127  【練習問題】ゲーム選手のリーグ分類                                     -           Knowledge                38
#             128  【練習問題】ステンレス板の欠陥分類                                     -           Knowledge                43
#             129  【練習問題】都市サイクルの燃料消費量予測                               -           Knowledge                70
#             130  【練習問題】天秤のバランス分類                                         -           Knowledge                54
#             132  【練習問題】ネット広告のクリック予測                                   -           Knowledge               140
#             133  【練習問題】画像ラベリング（10種類）                                   -                                   330
#             135  【練習問題】ネット画像の分類                                           -                                    71
#             262  【SOTA】国立国会図書館の画像データレイアウト認識                       2100-12-31  -                        55
#             263  【SOTA】産業技術総合研究所 衛星画像分析コンテスト                      2100-12-31  -                        32
#             264  【SOTA】マイナビ × SIGNATE Student Cup 2019: 賃貸物件の家賃予測        2100-12-31  -                       318
#             265  【練習問題】健診データによる肝疾患判定                                 -                                   443
#             266  【練習問題】民泊サービスの宿泊価格予測                                 -                                   458
#             267  【SOTA】海洋研究開発機構 熱帯低気圧（台風等）検出アルゴリズム作成      2100-12-31  -                        13
#             268  【SOTA】オプト レコメンドエンジン作成                                  2100-12-31                           27
#             269  【SOTA】アップル 引越し需要予測                                        2100-12-31  -                       265
#             270  【SOTA】Weather Challenge：雲画像予測                                  2100-12-31  -                         5
#             271  【SOTA】JR西日本 走行中の北陸新幹線車両台車部の着雪量予測              2100-12-31  -                        12
#             288  【SOTA】Sansan 名刺の項目予測                                          2100-12-31  -                        21
#             294  【練習問題】債務不履行リスクの低減                                     -                                   136
#             358  【練習問題】機械稼働音の異常検知                                       -                                    52
#             404  【練習問題】モノクロ顔画像の感情分類                                   -                                    42
#             406  【練習問題】鋳造製品の欠陥検出                                         -                                   126
#             409  【練習問題】株価の推移予測                                             -                                   134
#             471  医学論文の自動仕分けチャレンジ                                         2021-10-04  総額￥400,000           596
#             489  【AIQuest2021】PBL_01 需要予測・在庫最適化（小売業）ビジネス導入課題①  2022-02-05                          520
#             490  【AIQuest2021】PBL_01 需要予測・在庫最適化（小売業）ビジネス導入課題②  2022-02-05                          515
#             491  【AIQuest2021】PBL_01 需要予測・在庫最適化（小売業）ビジネス導入課題③  2022-02-05                          513
#             492  【AIQuest2021】PBL_01 需要予測・在庫最適化（小売業）AI課題             2022-02-05                          292
#   fileId  name                                           title                                                   size  updated_at
# --------  ---------------------------------------------  --------------------------------------------------  --------  -------------------
#     2201  PBL01_h_exercise4_question.pdf                 PBL01_需要予測・在庫最適化_h.演習④設問                734746  2021-08-20 09:33:52
#     2202  PBL01_i_exercise4_supplementary-documents.pdf  PBL01_需要予測・在庫最適化_i.演習④ガイドコンテンツ   1410304  2021-08-19 14:50:11
#     2114  sales_history.csv                              販売実績データ                                      33293020  2021-08-19 14:50:11
#     2115  item_categories.csv                            商品カテゴリーデータ                                  113142  2021-08-19 14:50:07
#     2116  category_names.csv                             カテゴリ名称データ                                       879  2021-08-19 14:50:07
#     2117  test.csv                                       評価用データ                                           31978  2021-08-19 14:50:07
#     2118  sample_submission.csv                          応募用サンプルファイル                                 26430  2021-08-19 14:50:07
#     2410  PBL01_sample_code.ipynb                        サンプルコード（9/18追加）                            107000  2021-09-18 11:24:06
#     2411  requirements.txt                               サンプルコードについて（9/18追加）                        82  2021-09-18 11:24:30
# requirements.txt
#
# category_names.csv
#
# sample_submission.csv
#
# test.csv
#
# PBL01_sample_code.ipynb
#
# item_categories.csv
#
# PBL01_h_exercise4_question.pdf
#
# PBL01_i_exercise4_supplementary-documents.pdf
#
# sales_history.csv
#
#
# Download completed.

# %%
# ディレクトリ内のデータの確認
# %ls
# Out:
# adc.json                                       requirements.txt
# category_names.csv                             sales_history.csv
# item_categories.csv                            sample_data/
# PBL01_h_exercise4_question.pdf                 sample_submission.csv
# PBL01_i_exercise4_supplementary-documents.pdf  test.csv
# PBL01_sample_code.ipynb

# %%
# Googleドライブのマウント
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# #baseline

# %%
'''
初期設定
'''

DATA_PATH = '/content/drive/My Drive/AIQuest2021/PBL_01_需要予測/Phase2/demand/processed_data/processed_train_test_df_without_zero.csv'
SAMPLESUB_PATH = 'sample_submission.csv'
SUB_PATH = '/content/drive/My Drive/AIQuest2021/PBL_01_需要予測/Phase2/demand/submit/demand_LightGBM_baseline_without_zero.csv'


# ライブラリのインポート
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# データの読み込み
df = pd.read_csv(DATA_PATH)
print(df.isnull().sum())
print(df.dtypes)

# object型の変数の取得
categories = df.columns[df.dtypes == 'object']
print(categories)

# label Encoding
for cat in categories:
    le = LabelEncoder() 
    print(cat)
    
    df[cat].fillna('missing', inplace=True)
    le = le.fit(df[cat])
    df[cat] = le.transform(df[cat])
    # LabelEncoderは数値に変換するだけであるため、最後にastype('category')としておく
    df[cat] = df[cat].astype('category') 

# trainとtestに分割
train = df[~df['sales'].isnull()]
test = df[df['sales'].isnull()]

# 説明変数と目的変数を指定
X_train = train.drop(['sales'], axis=1)
Y_train = train['sales']
X_test = test.drop(['sales'], axis=1)

'''
モデルの構築と評価
'''

# ライブラリのインポート
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# ハイパーパラメータの設定
params = {
    'objective':'regression',
    'random_seed':1234    
}

x_train, x_valid, y_train, y_valid = train_test_split(X_train, Y_train,
                                                      test_size=0.3, random_state=0,
                                                      shuffle=False)

lgb_train = lgb.Dataset(x_train, y_train)
lgb_eval = lgb.Dataset(x_valid, y_valid, reference=lgb_train)    
    
model = lgb.train(params,
                  lgb_train,
                  valid_sets=lgb_eval,
                  num_boost_round=1000, # 学習回数の実行回数
                  early_stopping_rounds=20, # early_stoppingの判定基準
                  verbose_eval=10)    
    
y_pred = model.predict(x_valid, num_iteration=model.best_iteration)
rmse = np.sqrt(mean_squared_error(y_valid, y_pred))
print(rmse)

# 特徴量重要度の表示
lgb.plot_importance(model, importance_type='gain',
                    max_num_features=15)

"""
予測精度：
2.091388490532537
"""

'''
テストデータの予測
'''

# テストデータにおける予測
pred = model.predict(X_test)

'''
提出
'''

# 提出用サンプルの読み込み
sub = pd.read_csv(SAMPLESUB_PATH, header=None)

# カラム1の値を置き換え
sub[1] = pred

# CSVファイルの出力
sub.to_csv(SUB_PATH, header=None, index=False)

"""
スコア：
3.7497572
"""
# Out:
# month_bining          0
# id                    0
# store_id              0
# sales              3060
# sales_before_12       0
# sales_before_11       0
# sales_before_10       0
# sales_before_9        0
# sales_before_8        0
# sales_before_7        0
# sales_before_6        0
# sales_before_5        0
# sales_before_4        0
# sales_before_3        0
# sales_before_2        0
# category_id           0
# category              0
# category_detail       0
# year                  0
# month                 0
# dtype: int64
# month_bining       float64
# id                 float64
# store_id           float64
# sales              float64
# sales_before_12    float64
# sales_before_11    float64
# sales_before_10    float64
# sales_before_9     float64
# sales_before_8     float64
# sales_before_7     float64
# sales_before_6     float64
# sales_before_5     float64
# sales_before_4     float64
# sales_before_3     float64
# sales_before_2     float64
# category_id          int64
# category            object
# category_detail     object
# year                 int64
# month                int64
# dtype: object
# Index(['category', 'category_detail'], dtype='object')
# category
# category_detail
# /usr/local/lib/python3.7/dist-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# Training until validation scores don't improve for 20 rounds.
# [10]	valid_0's l2: 12.9259
# [20]	valid_0's l2: 12.5614
# [30]	valid_0's l2: 12.4362
# [40]	valid_0's l2: 12.3983
# [50]	valid_0's l2: 12.3835
# [60]	valid_0's l2: 12.3547
# [70]	valid_0's l2: 12.3217
# [80]	valid_0's l2: 12.2886
# [90]	valid_0's l2: 12.2865
# [100]	valid_0's l2: 12.2852
# [110]	valid_0's l2: 12.2818
# [120]	valid_0's l2: 12.3014
# Early stopping, best iteration is:
# [107]	valid_0's l2: 12.2711
# 3.5030169574446273
# '\nスコア：\n3.7497572\n'
